# %% [markdown]
# # Python Tutorials | Statements and Blocks
# ## A statemet is determine by new lines and identation.

# %%
# Identation looks like this. The spaces added to the nest line of the if statement. 
a = 1
if a == 1:
    print("Hello")
# Out:
# Hello
