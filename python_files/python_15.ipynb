# %% [markdown]
# # Youtube Tutorials | Arithmetic Operators

# %%
# Some calculations
print(5 + 8)
# Out:
# 13

# %%
print(5 - 9)
# Out:
# -4

# %%
print(8 / 2)
# Out:
# 4.0

# %%
print(15*369)
# Out:
# 5535

# %%
# This calculates the quotient of a division
print(21//4)
# Out:
# 5

# %%
# This calculates the residue of a division
print(21%4)
# Out:
# 1

# %%
# Number to the power of
print(5 ** 2)
# Out:
# 25

# %%
# There is a math modulo for extra functions
import math as m 
print(m.pi)
# Out:
# 3.141592653589793
