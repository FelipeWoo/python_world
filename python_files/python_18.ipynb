# %% [markdown]
# # Youtube Tutorials | Comparison Operators

# %%
# Checking variables
a=15
b=21
print(a == b)
# Out:
# False

# %%
print(a>b)
# Out:
# False

# %%
print(a<b)
# Out:
# True

# %%
print(b!=a)
# Out:
# True
