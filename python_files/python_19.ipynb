# %% [markdown]
# # Youtube Tutorials | Membership & Operators

# %%
a_age = 15
b_age = 17

club = ['Anne', 'Jake', 'Bill']

print('Collin' in club)
# Out:
# False

# %%
print('Anne' in club)
# Out:
# True
