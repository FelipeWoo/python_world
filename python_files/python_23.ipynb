# %% [markdown]
# # Python Tutorials | User Input

# %%
name = input('Enter your name = ')

# %%
if name == '':
    print('Do not leave the field blank.')
elif not name.isalpha():
    print('Only alphabetical letters allowed.')
else:
    print(f'Welcome, {name}')
# Out:
# Welcome, Pepe

# %%
# For passwords you ca use getpass
from getpass import getpass

passw = getpass('Enter your pass = ')
print(f'Password, {passw}')
# Out:
# Password, 5494694
